# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
import shutil

# %%
#df = pd.read_csv('kahn.csv')
df = pd.read_csv('excluded_france_photos.tsv', sep='\t')

# %%
df['Opérateur'].value_counts()
# Out:
# Opérateur
# Frédéric Gadmer                      12275
# Roger Dumas                           4312
# Auguste Léon                          3681
# Stéphane Passet                       2146
# Georges Chevalier                     1802
# Fernand Cuville                       1114
# Paul Castelnau                         621
# opérateur non mentionné                418
# Camille Sauvageot                       88
# Jules Gervais-Courtellemont             84
# Anders Beer Wilse                       70
# Jean Brunhes                            15
# Stéphane Passet,Frédéric Gadmer          8
# Georges Chevalier,Fernand Cuville        3
# Auguste Léon,Anders Beer Wilse           2
# Roger Dumas,Stéphane Passet              2
# Stéphane Passet,Roger Dumas              2
# Stéphane Passet,Auguste Léon             1
# Fernand Cuville,Stéphane Passet          1
# Charles Winckelsen                       1
# Name: count, dtype: int64

# %%
df['Opérateur'].value_counts()[::-1].plot.barh(color='black', edgecolor='white')
# Out:
# <Axes: ylabel='Opérateur'>
